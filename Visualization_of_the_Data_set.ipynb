# %% [markdown]
# <a href="https://colab.research.google.com/github/TLG442/Research_Project/blob/electricity-consumption-prediction-model%2Fit21222740/Visualization_of_the_Data_set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
pythonafroz_electricity_smart_meter_data_from_india_path = kagglehub.dataset_download('pythonafroz/electricity-smart-meter-data-from-india')

print('Data source import complete.')
# Out:
# ...
# 100%|██████████| 176M/176M [00:01<00:00, 118MB/s]
# Extracting files...
# Data source import complete.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")# This Python 3 environment comes with many helpful analytics libraries installed

# %%
import os
import pandas as pd

# Assuming the dataset is stored in the path returned by kagglehub
dataset_path = pythonafroz_electricity_smart_meter_data_from_india_path

# List the files in the dataset directory
print(os.listdir(dataset_path))

# Load the CSV files
df_2020 = pd.read_csv(os.path.join(dataset_path, "CEEW - Smart meter data Bareilly 2020.csv"))
df_2021 = pd.read_csv(os.path.join(dataset_path, "CEEW - Smart meter data Bareilly 2021.csv"))

# Display the first few rows to ensure it's loaded correctly
print(df_2020.head())
print(df_2021.head())
# Out:
# ['SM Cleaned Data MH2021.csv', 'CEEW - Smart meter data Mathura 2020.csv', 'CEEW - Smart meter data Mathura 2019.csv', 'CEEW - Smart meter data Bareilly 2020.csv', 'SM Cleaned Data BR2019.csv', 'CEEW - Smart meter data Bareilly 2021.csv', 'SM Cleaned Data MH Aggregated.csv', 'SM Cleaned Data BR Aggregated.csv']
#            x_Timestamp  t_kWh  z_Avg Voltage (Volt)  z_Avg Current (Amp)  \
# 0  2020-01-01 00:00:00  0.002                251.26                 0.15
# 1  2020-01-01 00:03:00  0.001                251.23                 0.15
# 2  2020-01-01 00:06:00  0.001                251.55                 0.14
# 3  2020-01-01 00:09:00  0.001                251.97                 0.14
# 4  2020-01-01 00:12:00  0.002                252.03                 0.14
#
#    y_Freq (Hz) meter
# 0        49.97  BR02
# 1        49.94  BR02
# 2        49.94  BR02
# 3        50.09  BR02
# 4        50.08  BR02
#            x_Timestamp  t_kWh  z_Avg Voltage (Volt)  z_Avg Current (Amp)  \
# ...

# %%
df_2020 = df_2020.sample(frac= 0.01)
df_2021 = df_2021.sample(frac= 0.01)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot t_kWh over time
plt.figure(figsize=(14, 6))
plt.plot(df_2020['x_Timestamp'], df_2020['t_kWh'], label='2020', color='blue')
plt.plot(df_2021['x_Timestamp'], df_2021['t_kWh'], label='2021', color='orange')
plt.title('Energy Consumption (t_kWh) Over Time')
plt.xlabel('Timestamp')
plt.ylabel('Energy (kWh)')
plt.legend()
plt.show()

# %%
# Plot z_Avg Voltage over time
plt.figure(figsize=(14, 6))
plt.plot(df_2020['x_Timestamp'], df_2020['z_Avg Voltage (Volt)'], label='2020', color='blue')
plt.plot(df_2021['x_Timestamp'], df_2021['z_Avg Voltage (Volt)'], label='2021', color='orange')
plt.title('Average Voltage Over Time')
plt.xlabel('Timestamp')
plt.ylabel('Voltage (Volt)')
plt.legend()
plt.show()

# %%
# Plot histograms of Voltage for both years
plt.figure(figsize=(12, 6))
sns.histplot(df_2020['z_Avg Voltage (Volt)'], color='blue', label='2020', kde=True)
sns.histplot(df_2021['z_Avg Voltage (Volt)'], color='orange', label='2021', kde=True)
plt.title('Distribution of Average Voltage')
plt.xlabel('Voltage (Volt)')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
# Plot histograms of Current for both years
plt.figure(figsize=(12, 6))
sns.histplot(df_2020['z_Avg Current (Amp)'], color='blue', label='2020', kde=True)
sns.histplot(df_2021['z_Avg Current (Amp)'], color='orange', label='2021', kde=True)
plt.title('Distribution of Average Current')
plt.xlabel('Current (Amp)')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
# Boxplot to compare t_kWh for both years
plt.figure(figsize=(10, 6))
sns.boxplot(data=[df_2020['t_kWh'], df_2021['t_kWh']], palette="Set2")
plt.xticks([0, 1], ['2020', '2021'])
plt.title('Comparison of Energy Consumption (t_kWh) Between 2020 and 2021')
plt.ylabel('Energy (kWh)')
plt.show()

# %%
# Heatmap for correlations in 2020 data
plt.figure(figsize=(10, 8))
corr_2020 = df_2020[['t_kWh', 'z_Avg Voltage (Volt)', 'z_Avg Current (Amp)', 'y_Freq (Hz)']].corr()
sns.heatmap(corr_2020, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix for 2020 Data')
plt.show()

# %%
# Heatmap for correlations in 2021 data
plt.figure(figsize=(10, 8))
corr_2021 = df_2021[['t_kWh', 'z_Avg Voltage (Volt)', 'z_Avg Current (Amp)', 'y_Freq (Hz)']].corr()
sns.heatmap(corr_2021, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix for 2021 Data')
plt.show()
